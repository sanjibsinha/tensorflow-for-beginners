# %% [markdown]
# <a href="https://colab.research.google.com/github/sanjibsinha/tensorflow-for-beginners/blob/numpy-matplotlib-pandas/pandas_demo_seven.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

people = {
    "Firstname" : ["John", "Json", "James"],
    "Lastname" : ["Smith", "Web", "Bond"],
    "Location" : ["New York", "Munich", "London"],
}

people["Firstname"]
# Out:
# ['John', 'Json', 'James']

# %%
df = pd.DataFrame(people)
df
# Out:
#   Firstname Lastname  Location
# 0      John    Smith  New York
# 1      Json      Web    Munich
# 2     James     Bond    London

# %%
df['Firstname'] + ' ' + df['Lastname']
# Out:
# 0    John Smith
# 1      Json Web
# 2    James Bond
# dtype: object

# %%
df['Name'] = df['Firstname'] + ' ' + df['Lastname']
df
# Out:
#   Firstname Lastname  Location        Name
# 0      John    Smith  New York  John Smith
# 1      Json      Web    Munich    Json Web
# 2     James     Bond    London  James Bond

# %%
df.drop(columns=['Firstname', 'Lastname'], inplace=True)

df
# Out:
#    Location        Name
# 0  New York  John Smith
# 1    Munich    Json Web
# 2    London  James Bond

# %%
df['Name'].str.split(' ', expand=True)

df
# Out:
#    Location        Name
# 0  New York  John Smith
# 1    Munich    Json Web
# 2    London  James Bond

# %%
df[['Firstname', 'Lastname']] = df['Name'].str.split(' ', expand=True)
df
# Out:
#    Location        Name Firstname Lastname
# 0  New York  John Smith      John    Smith
# 1    Munich    Json Web      Json      Web
# 2    London  James Bond     James     Bond
