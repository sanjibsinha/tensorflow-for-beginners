# %% [markdown]
# <a href="https://colab.research.google.com/github/sanjibsinha/tensorflow-for-beginners/blob/google-colabs/matplotlib_categorical_variables.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt


names = ['Mary', 'John', 'Json', 'Emily', 'Mark', 'Karl', 'Cecil', 'Epstein', 'Maxwell']
values = [96, 87, 78, 91, 63, 99, 51, 20, 28]

plt.figure(figsize=(27, 9))

plt.subplot(131)
plt.bar(names, values)
plt.subplot(132)
plt.scatter(names, values)
plt.subplot(133)
# plt.plot(names, values)

plt.plot(names, values, 'go--', linewidth=4.0, markersize=12)

# lines = plt.plot(names, values)
# use keyword arguments
# plt.setp(lines, color='r', linewidth=4.0)
# or MATLAB style string value pairs
# plt.setp(lines, 'color', 'r', 'linewidth', 4.0)

plt.suptitle('Categorical Plotting')
plt.show()
